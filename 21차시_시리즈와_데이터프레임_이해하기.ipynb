# %% [markdown]
# <a href="https://colab.research.google.com/github/hearthatu/Basic-Python/blob/main/21%EC%B0%A8%EC%8B%9C_%EC%8B%9C%EB%A6%AC%EC%A6%88%EC%99%80_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84_%EC%9D%B4%ED%95%B4%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

s = pd.Series([100, 200, 300],index=['A','B','C'])
s
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
s.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
s.values # 리스트가 아닌, 행렬
# Out:
# array([100, 200, 300])

# %%
df = pd.DataFrame({"이름":["홍길동","이순신","강동원","아이유"],
                   "성별":["남자","남자","남자","여자"],
                   "나이":[40, 50, 30,20 ]},
                  index=["가","나","다","라"], columns = ["성별","나이","이름"])
df
# Out:
#    성별  나이   이름
# 가  남자  40  홍길동
# 나  남자  50  이순신
# 다  남자  30  강동원
# 라  여자  20  아이유

# %%
box = [["홍길동","남자","40"],["이순신","남자",50],["아이유","여자",20]]
pd.DataFrame(box, columns = ["이름","성별","나이"])
# Out:
#     이름  성별  나이
# 0  홍길동  남자  40
# 1  이순신  남자  50
# 2  아이유  여자  20
