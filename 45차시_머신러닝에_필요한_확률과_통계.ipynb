# %% [markdown]
# <a href="https://colab.research.google.com/github/hearthatu/Basic-Python/blob/main/45%EC%B0%A8%EC%8B%9C_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EC%97%90_%ED%95%84%EC%9A%94%ED%95%9C_%ED%99%95%EB%A5%A0%EA%B3%BC_%ED%86%B5%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #머신러닝에 필요한 확률과 통계
#
# 1. 평균
#
# ```
# score = np.array([42,69,56,41,57])
# np.mean(score)
# scores_df.mean()
# ```
#
# 2. 중앙값
#
# ```
# score = np.array([42,69,56,41,57])
# np.median(scores)
# scores_df.median()
# ```
#
# 3. 최빈값
#
# ```
# pd.Series([1,1,1,2,2,3]).mode()
#
# ```
#
# 4. 편차
#
# ```
# score = np.array([42,69,56,41,57])
#
# mean = np.mean(scores)
# deviation = scores - mean
# deviation
# ```
# 5. 분산, 표준편차
#
# ```
# #편차들을 제곱한 값의 합의 평균
# np.var(scores)
#
# #표준편차
# np.sqrt(np.var(scores))
# ```
#
# 6. 데이터 정규화
#
# > 시험점수가 동일하더라도, 쉬운 시험과 어려운 시험에서의 60점은 상대적인 결과는 다르다.
#
# > **즉, 점수는 평균과 분산에 따라 평가가 달라진다.**
#
# > 데이터를 통일된 지표로 변환하는 것을 정규화라 한다.
#
#
# 7. 데이터 표준화
#
# ```
# z = (scores - np.mean(scores)) / np.std(scores)
# z
#
# # 표준화하는 경우 평균 0, 표준편차 1이 된다.
# ```
#
# 8. 두 데이터 사이의 관계를 나타내는 지표
#
# - 산점도
#
# 9. 상관계수
#
# - 상관계수는 -1부터 1사이의 값을 갖고, 1 또는 -1에 가까워질수록 높은 상관관계를 갖는다는 의미이고, 0에 가까울수록 서로 상관관계가 없다고 볼 수 있다
#
# ```
# df.corr()
# ```
#
# 10. 모집단과 표본
#
# - 추측하고 싶은 관측 대상 전체 : 모집단
# - 추측에 사용하는 관측 대상의 무작위 일부분 : 표본
#
# ```
# box = [1,2,3,4,5,6,7,8,9,0]
# random.sample(box, 5)
#
# >>> [3,1,2,8,5]
# ```
#
# 11. 확률
#
# - 취하는 값과 그 값이 나올 확률이 결정되어 있는 것을 확률 변수라 한다.
#
# 12. 확률의 성질
#
# - 확률은 절대적으로 0이상의 값을 갖는다.
# - 모든 확률을 더하면 1이 된다.
