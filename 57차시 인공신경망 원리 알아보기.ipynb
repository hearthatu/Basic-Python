# %% [markdown]
# <a href="https://colab.research.google.com/github/hearthatu/Basic-Python/blob/main/57%EC%B0%A8%EC%8B%9C%20%EC%9D%B8%EA%B3%B5%EC%8B%A0%EA%B2%BD%EB%A7%9D%20%EC%9B%90%EB%A6%AC%20%EC%95%8C%EC%95%84%EB%B3%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 인공신경망
#
# - 인공신경망
#
# > 인공신경망(Artificial Neural NetWork, ANN)은 사람의 뇌 속 뉴런의 작용을 모방한 머신러닝 모델 입력층, 은닉층, 출력층으로 구성되어 있고 은닉층이 포함되어 있는 모델이 딥러닝이다.
#
# - 경사하강법
#
# > 함수의 기울기를 구하고 경사의 절댓값이 낮은 쪽으로 계속 이동시키고 극 값에 이를 때까지 반복해서 학습하는 방법이다.

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2,4,6,8])
y = np.array([30, 75, 55, 90])

a1= 0
b = 0
lr = 0.005

# %%
plt.scatter(x1, y)
plt.plot(x1, a1*x1 + b, "red")

# %%
for i in range(1, 3001):
    y_hat = a1 * x1 + b
    error = y_hat - y

    a1_diff = sum(2*error*x1)
    b_diff = sum(2 * error * 1)

    a1 = a1 - a1_diff * lr
    b = b - b_diff * lr

    print("{}회 학습 / 기울기 {} / 절편 {}".format(1, a1, b))
# Out:
# 1회 학습 / 기울기 14.1 / 절편 2.5
# 1회 학습 / 기울기 10.780000000000001 / 절편 2.08
# 1회 학습 / 기울기 11.528 / 절편 2.3407999999999998
# 1회 학습 / 기울기 11.32624 / 절편 2.4415679999999997
# 1회 학습 / 기울기 11.346438399999998 / 절편 2.57865728
# 1회 학습 / 기울기 11.314980864 / 절편 2.7062233088000003
# 1회 학습 / 기울기 11.295759165439998 / 절편 2.834978203648
# 1회 학습 / 기울기 11.273852526182399 / 절편 2.96242724241408
# 1회 학습 / 기울기 11.252744046280704 / 절편 3.0891596474810368
# 1회 학습 / 기울기 11.231619261247651 / 절편 3.2150444523256545
# 1회 학습 / 기울기 11.210667257285339 / 절편 3.340118821983098
# 1회 학습 / 기울기 11.189842784146313 / 절편 3.4643806176467065
# 1회 학습 / 기울기 11.169155319641396 / 절편 3.5878368361115758
# 1회 학습 / 기울기 11.148601568849406 / 절편 3.7104922987388336
# 1회 학습 / 기울기 11.128181226482353 / 절편 3.832352293019399
# 1회 학습 / 기울기 11.10789329609965 / 절편 3.9534219560021526
# 1회 학습 / 기울기 11.087736949579638 / 절편 4.0737064185421366
# 1회 학습 / 기울기 11.067711326375646 / 절편 4.193210771884524
# 1회 학습 / 기울기 11.047815580347967 / 절편 4.311940075734014
# ...

# %%
plt.scatter(x1, y)
plt.plot(x1, a1*x1 + b, "red")

# %%
a1 * 5 + b
# Out:
# 62.499999988884035
