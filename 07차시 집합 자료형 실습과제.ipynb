# %%
#list1 = [1,1,1,1,2,2,2,2,4,4,4,4,5,5,5,5,5,3,3,3,3]

#리스트 값이 들어있는 변수 list1을 (5,4,3,2,1) 로 변환한 후,

#set1 = set([3,4,5,6,7])

#변수 set1과의 교집합, 합집합을 화면에 출력해보세요


a = [1,1,1,1,2,2,2,2,4,4,4,4,5,5,5,5,5,3,3,3,3]
b = set([3,4,5,6,7])
a = set(a)
#print(a)

a = list(a)
a.sort(reverse=True)
print(a)
a = tuple(a)
print(a)

set(a)

print("교집합", set(a) & b)
print("합집합", set(a) | b)

# union, intersection
# print(5 in a) --> member operation
